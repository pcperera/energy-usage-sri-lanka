# %%
import pandas as pd

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.read_csv('data/239171B_data_file_2_candidate_2.csv')

# %%
df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %%
df['Method'].unique()
# Out:
# array(['Google Sheet', 'Face', 'Telephone'], dtype=object)

# %%
df.describe()
# Out:
#        How many stories does your house have?  \
# count                                58.00000
# mean                                  1.50000
# std                                   0.65561
# min                                   0.00000
# 25%                                   1.00000
# 50%                                   1.00000
# 75%                                   2.00000
# max                                   4.00000
#
#        How much is your household's average monthly expenditure in LKR for "food" items ?  \
# count                                          58.000000
# mean                                        74482.758621
# std                                        114863.342354
# min                                         20000.000000
# 25%                                         40000.000000
# 50%                                         50000.000000
# 75%                                         75000.000000
# ...

# %%
df.columns
# Out:
# Index(['Method', 'Timestamp',
#        'Which of the following time periods best describes when your house was built?',
#        'What do you know about the architecture of the house?',
#        'Select the best option which describes your house',
#        'How many stories does your house have?',
#        'State the area of your house in square feet?',
#        'Relationship to the head of the household', 'Gender',
#        'Current attendance at school or other educational institution',
#        'Main occupation',
#        'How much is your household's average monthly expenditure in LKR for "food" items ?',
#        'How much is your household's average monthly expenditure in LKR for "non-food" items ?',
#        'What is the best representation of the major material your outside walls are made of?',
#        'Which of the following options do your house use for ventilation and lighting other than windows and doors (only indoors)?',
# ...

# %%
df[df['Method'] == 'Google Sheet']
# Out:
#           Method   Timestamp  \
# 0   Google Sheet  2023-06-14
# 1   Google Sheet  2023-06-14
# 3   Google Sheet  2023-06-14
# 6   Google Sheet  2023-06-14
# 10  Google Sheet  2023-06-14
# 11  Google Sheet  2023-06-14
# 13  Google Sheet  2023-06-15
# 14  Google Sheet  2023-06-16
# 16  Google Sheet  2023-06-16
# 18  Google Sheet  2023-06-16
# 19  Google Sheet  2023-06-16
# 21  Google Sheet  2023-06-16
# 22  Google Sheet  2023-06-17
# 24  Google Sheet  2023-06-18
# 25  Google Sheet  2023-06-18
# 26  Google Sheet  2023-06-18
# 28  Google Sheet  2023-06-18
# 31  Google Sheet  2023-06-18
# 33  Google Sheet  2023-06-18
# 34  Google Sheet  2023-06-18
# 35  Google Sheet  2023-06-18
# 37  Google Sheet  2023-06-18
# 38  Google Sheet  2023-06-18
# 46  Google Sheet  2023-06-19
# 48  Google Sheet  2023-06-19
# 53  Google Sheet  2023-06-19
# 55  Google Sheet  2023-06-21
# 57  Google Sheet  2023-06-22
#
#    Which of the following time periods best describes when your house was built?  \
# ...

# %%
df[df['Method'] == 'Face']
# Out:
#    Method   Timestamp  \
# 2    Face  2023-06-14
# 8    Face  2023-06-14
# 9    Face  2023-06-14
# 15   Face  2023-06-16
# 17   Face  2023-06-16
# 23   Face  2023-06-18
# 29   Face  2023-06-18
# 30   Face  2023-06-18
# 32   Face  2023-06-18
# 36   Face  2023-06-18
# 39   Face  2023-06-18
# 42   Face  2023-06-18
# 45   Face  2023-06-19
# 49   Face  2023-06-19
# 52   Face  2023-06-19
#
#    Which of the following time periods best describes when your house was built?  \
# 2                                           2000-2009
# 8                                           2010-2019
# 9                                           2000-2009
# 15                                        Before 1980
# 17                                          1990-1999
# 23                                          2000-2009
# 29                                          2000-2009
# 30                                          2000-2009
# 32                                        Before 1980
# ...

# %%
df[df['Method'] == 'Telephone']
# Out:
#        Method   Timestamp  \
# 4   Telephone  2023-06-14
# 5   Telephone  2023-06-14
# 7   Telephone  2023-06-14
# 12  Telephone  2023-06-14
# 20  Telephone  2023-06-16
# 27  Telephone  2023-06-18
# 40  Telephone  2023-06-18
# 41  Telephone  2023-06-18
# 43  Telephone  2023-06-18
# 44  Telephone  2023-06-18
# 47  Telephone  2023-06-19
# 50  Telephone  2023-06-19
# 51  Telephone  2023-06-19
# 54  Telephone  2023-06-20
# 56  Telephone  2023-06-21
#
#    Which of the following time periods best describes when your house was built?  \
# 4                                           1980-1989
# 5                                          After 2019
# 7                                           1990-1999
# 12                                         After 2019
# 20                                          2000-2009
# 27                                          2000-2009
# 40                                          2000-2009
# 41                                         After 2019
# ...

# %%
df.columns
# Out:
# Index(['Method', 'Timestamp',
#        'Which of the following time periods best describes when your house was built?',
#        'What do you know about the architecture of the house?',
#        'Select the best option which describes your house',
#        'How many stories does your house have?',
#        'State the area of your house in square feet?',
#        'Relationship to the head of the household', 'Gender',
#        'Current attendance at school or other educational institution',
#        'Main occupation',
#        'How much is your household's average monthly expenditure in LKR for "food" items ?',
#        'How much is your household's average monthly expenditure in LKR for "non-food" items ?',
#        'What is the best representation of the major material your outside walls are made of?',
#        'Which of the following options do your house use for ventilation and lighting other than windows and doors (only indoors)?',
# ...

# %%
df['How much is your household\'s average monthly expenditure in LKR for "food" items ?'].unique()
# Out:
# array([100000,  60000,  30000,  20000, 150000,  50000, 900000,  40000,
#         25000,  80000,  45000,  55000,  75000,  35000])

# %%
df['How much is your household\'s average monthly expenditure in LKR for "non-food" items ?'].unique()
# Out:
# array([150000,  80000,  30000, 100000, 200000,  60000,  50000,  25000,
#         35000, 120000,  20000,  75000,  10000,  90000,  40000,  15000,
#        160000])

# %%
df['Which Secretarial division your house belonged?'].unique()
# Out:
# array(['Hikkaduwa', 'Mahara', 'Kaduwela', 'Ratmalana', 'Negombo',
#        'Biyagama', 'Padukka', 'Thihagoda', 'Matara', 'Eheliyagoda',
#        'Dompe', 'Ambalangoda', 'Homagama', 'Gampahaa', 'Weligama',
#        'Kandy', 'Attanagalla', 'Jaela', 'Kalutara', 'Horana', 'Kesbewa',
#        'Imbulpe', 'Colombo central', 'Pelmadulla', 'Gampaha', 'Kotte',
#        'Baddema', 'Ja ela', 'Baddegama', 'Bandaragama', 'Delgoda',
#        'Thanamalwila', 'Panadura',
#        'Nugegoda ( sri jayawardena pura kotte )', 'Maharagama', 'Wekada',
#        'Wellawatte', 'Bandarawela'], dtype=object)

# %%
# # Save the DataFrame to a CSV file
# df.to_csv('data/239171B_data_file_2.csv', index=False)

# %%
# new_df = pd.read_csv('data/239171B_data_file_2.csv')

# %%
df.columns
# Out:
# Index(['Method', 'Timestamp',
#        'Which of the following time periods best describes when your house was built?',
#        'What do you know about the architecture of the house?',
#        'Select the best option which describes your house',
#        'How many stories does your house have?',
#        'State the area of your house in square feet?',
#        'Relationship to the head of the household', 'Gender',
#        'Current attendance at school or other educational institution',
#        'Main occupation',
#        'How much is your household's average monthly expenditure in LKR for "food" items ?',
#        'How much is your household's average monthly expenditure in LKR for "non-food" items ?',
#        'What is the best representation of the major material your outside walls are made of?',
#        'Which of the following options do your house use for ventilation and lighting other than windows and doors (only indoors)?',
# ...

# %%
df
# Out:
#           Method   Timestamp  \
# 0   Google Sheet  2023-06-14
# 1   Google Sheet  2023-06-14
# 2           Face  2023-06-14
# 3   Google Sheet  2023-06-14
# 4      Telephone  2023-06-14
# 5      Telephone  2023-06-14
# 6   Google Sheet  2023-06-14
# 7      Telephone  2023-06-14
# 8           Face  2023-06-14
# 9           Face  2023-06-14
# 10  Google Sheet  2023-06-14
# 11  Google Sheet  2023-06-14
# 12     Telephone  2023-06-14
# 13  Google Sheet  2023-06-15
# 14  Google Sheet  2023-06-16
# 15          Face  2023-06-16
# 16  Google Sheet  2023-06-16
# 17          Face  2023-06-16
# 18  Google Sheet  2023-06-16
# 19  Google Sheet  2023-06-16
# 20     Telephone  2023-06-16
# 21  Google Sheet  2023-06-16
# 22  Google Sheet  2023-06-17
# 23          Face  2023-06-18
# 24  Google Sheet  2023-06-18
# 25  Google Sheet  2023-06-18
# 26  Google Sheet  2023-06-18
# 27     Telephone  2023-06-18
# 28  Google Sheet  2023-06-18
# 29          Face  2023-06-18
# 30          Face  2023-06-18
# ...

# %%
df.shape
# Out:
# (58, 28)

# %%
for column in df.columns:
    print(f'Column Name = {column}')
    print(df[column].unique())
# Out:
# Column Name = Method
# ['Google Sheet' 'Face' 'Telephone']
# Column Name = Timestamp
# ['2023-06-14' '2023-06-15' '2023-06-16' '2023-06-17' '2023-06-18'
#  '2023-06-19' '2023-06-20' '2023-06-21' '2023-06-22']
# Column Name = Which of the following time periods best describes when your house was built?
# ['Before 1980' '2000-2009' '1980-1989' 'After 2019' '1990-1999'
#  '2010-2019']
# Column Name = What do you know about the architecture of the house?
# ['I am not aware of it'
#  'House was designed barely to pass the statutory requirements of the local authorities.'
#  'No such professional designing was done; the house was designed to suit our needs and wants.'
#  'The house was designed by a certified architect.'
#  'House was not specifically designed by an architect, but the plan was inspected by a certified architect/engineer.'
#  'Other']
# Column Name = Select the best option which describes your house
# ...

# %%
df['Which district you are residing?'].replace('Kaluthara', 'Kalutara', inplace=True)

# %%
df['Which district you are residing?'].unique()
# Out:
# array(['Galle', 'Gampaha', 'Colombo', 'Matara', 'Ratnapura', 'Kandy',
#        'Kalutara', 'Monaragala', 'Badulla'], dtype=object)

# %%
df['Which Secretarial division your house belonged?'].replace('Kaluthara', 'Kalutara', inplace=True)

# %%
df['Which Secretarial division your house belonged?'].unique()
# Out:
# array(['Hikkaduwa', 'Mahara', 'Kaduwela', 'Ratmalana', 'Negombo',
#        'Biyagama', 'Padukka', 'Thihagoda', 'Matara', 'Eheliyagoda',
#        'Dompe', 'Ambalangoda', 'Homagama', 'Gampahaa', 'Weligama',
#        'Kandy', 'Attanagalla', 'Jaela', 'Kalutara', 'Horana', 'Kesbewa',
#        'Imbulpe', 'Colombo central', 'Pelmadulla', 'Gampaha', 'Kotte',
#        'Baddema', 'Ja ela', 'Baddegama', 'Bandaragama', 'Delgoda',
#        'Thanamalwila', 'Panadura',
#        'Nugegoda ( sri jayawardena pura kotte )', 'Maharagama', 'Wekada',
#        'Wellawatte', 'Bandarawela'], dtype=object)

# %%
#df.to_csv('data/239171B_data_file_2_candidate_3.csv', index=False)
